# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 1.show the count of different types of species

# %%
data=pd.read_csv("Iris.csv")
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %% [markdown]
# # find the max,min and mean in values of Sepallength, petallength,  sepalwidth and petalwidth

# %%
print('maximum value ',data['SepalLengthCm'].max())
print('manimum value ',data['SepalLengthCm'].min())
print('mean value ',data['SepalLengthCm'].mean())
# Out:
# maximum value  7.9
# manimum value  4.3
# mean value  5.843333333333335

# %%
print('maximum value ',data['PetalLengthCm'].max())
print('manimum value ',data['PetalLengthCm'].min())
print('mean value ',data['PetalLengthCm'].mean())
# Out:
# maximum value  6.9
# manimum value  1.0
# mean value  3.7586666666666693

# %%
print('maximum value ',data['SepalWidthCm'].max())
print('manimum value ',data['SepalWidthCm'].min())
print('mean value ',data['SepalWidthCm'].mean())
# Out:
# maximum value  4.4
# manimum value  2.0
# mean value  3.0540000000000007

# %%
print('maximum value ',data['PetalWidthCm'].max())
print('manimum value ',data['PetalWidthCm'].min())
print('mean value ',data['PetalWidthCm'].mean())
# Out:
# maximum value  2.5
# manimum value  0.1
# mean value  1.1986666666666672

# %% [markdown]
# # 3. scatterplot(for sepallength and petallength)

# %%
a=data["SepalWidthCm"]
b=data['PetalLengthCm']
c=data['SepalLengthCm']
d=data['PetalWidthCm']
s=data["Species"]
plt.scatter(a,b,color='orange')
plt.xlabel('SepalWidthCm')
plt.ylabel('PetalLengthCm')
# Out:
# Text(0, 0.5, 'PetalLengthCm')

# %% [markdown]
# # 4. bargraph (for sepallength and petallength)

# %%
plt.bar(c,b,color='m')
plt.xlabel('SepalWidthCm')
plt.ylabel('PetalLengthCm')
# Out:
# Text(0, 0.5, 'PetalLengthCm')

# %% [markdown]
# # 5.jointplot(for sepallength and sepalwidth)

# %%
sns.jointplot(c,a,color='r')

# %% [markdown]
# # 6. facetgrid(for sepallength and sepalwidth for all species)

# %%
r=sns.load_dataset('Iris')
g = sns.FacetGrid(r, col="sepal_length",row='sepal_width')
g.map(plt.hist,"species")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-08b0572216cb> in <module>
#       1 r=sns.load_dataset('Iris')
#       2 g = sns.FacetGrid(r, col="sepal_length",row='sepal_width')
# ----> 3 g.map(plt.hist,"species")
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     752
#     753             # Draw the plot
# --> 754             self._facet_plot(func, ax, plot_args, kwargs)
#     755
#     756         # Finalize the annotations and layout
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     836
#     837         # Draw the plot
# --> 838         func(*plot_args, **plot_kwargs)
#     839
#     840         # Sort out the supporting information
#
# ...

# %% [markdown]
# # 7.boxplot(for species and sepalwidth)

# %%
sns.boxplot(s,a)

# %% [markdown]
# # 8.boxplot & stripplot(for sepallength and all species)

# %%
sns.boxplot(c,s)

# %%
sns.stripplot(c,s)

# %% [markdown]
# # 9. violinplot(for petallength and all species)

# %%
sns.violinplot(b,s)

# %% [markdown]
# # 10.pairplot(for all 4 columns with species)

# %%
sns.pairplot(data)
